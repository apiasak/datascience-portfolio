# %% [markdown]
# <a href="https://colab.research.google.com/github/apiasak/datascience-portfolio/blob/main/code/ecommercetools_Example_usage_with_Retail_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EcommerceTools
#
# https://github.com/practical-data-science/ecommercetools

# %%
# !pip install ecommercetools --upgrade --quiet

# %%
import pandas as pd

# %% [markdown]
# ## EcommerceTools > Transactions

# %%
from ecommercetools import utilities
from ecommercetools import transactions

# %% [markdown]
# ### 1. Load a sample transaction items dataset

# %%
transaction_items = utilities.load_sample_data()
transaction_items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   order_id     541909 non-null  object
#  1   sku          541909 non-null  object
#  2   description  540455 non-null  object
#  3   quantity     541909 non-null  int64
#  4   order_date   541909 non-null  datetime64[ns]
#  5   unit_price   541909 non-null  float64
#  6   customer_id  406829 non-null  float64
#  7   country      541909 non-null  object
#  8   line_price   541909 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(4)
# memory usage: 37.2+ MB

# %% [markdown]
# ### 2. Format a custom transaction items dataset

# %%
sales = pd.read_excel('https://archive.ics.uci.edu/ml/machine-learning-databases/00352/Online%20Retail.xlsx')

# %%
df = sales.rename(columns={
        'InvoiceDate': 'order_date',
        'InvoiceNo': 'order_id',
        'CustomerID': 'customer_id',
        'StockCode': 'sku',
        'Quantity': 'quantity',
        'UnitPrice': 'unit_price'
    })

# %%
df['line_price'] = round(df['quantity'] * df['unit_price'], 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   order_id     541909 non-null  object
#  1   sku          541909 non-null  object
#  2   Description  540455 non-null  object
#  3   quantity     541909 non-null  int64
#  4   order_date   541909 non-null  datetime64[ns]
#  5   unit_price   541909 non-null  float64
#  6   customer_id  406829 non-null  float64
#  7   Country      541909 non-null  object
#  8   line_price   541909 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(4)
# memory usage: 37.2+ MB

# %%
transaction_items = df

# %% [markdown]
# ### 3. Create a transactions dataset

# %%
transactions_df = transactions.get_transactions(df)
transactions_df.head()
# Out:
#   order_id          order_date  customer_id  skus  items  revenue  \
# 0   536365 2010-12-01 08:26:00      17850.0     7     40   139.12
# 1   536366 2010-12-01 08:28:00      17850.0     2     12    22.20
# 2   536367 2010-12-01 08:34:00      13047.0    12     83   278.73
# 3   536368 2010-12-01 08:34:00      13047.0     4     15    70.05
# 4   536369 2010-12-01 08:35:00      13047.0     1      3    17.85
#
#    replacement  order_number
# 0            0             1
# 1            0             2
# 2            0             1
# 3            0             2
# 4            0             3

# %% [markdown]
# # EcommerceTools > Products

# %%
from ecommercetools import products

# %% [markdown]
# ### 1. Create a products dataset

# %%
products_df = products.get_products(transaction_items)
products_df.head()
# Out:
#      sku    first_order_date     last_order_date  customers  orders  items  \
# 0  10002 2010-12-01 08:45:00 2011-04-28 15:05:00         40      73   1037
# 1  10080 2011-02-27 13:47:00 2011-11-21 17:04:00         19      24    495
# 2  10120 2010-12-03 11:19:00 2011-12-04 13:15:00         25      29    193
# 3  10125 2010-12-01 12:23:00 2011-12-09 10:13:00         49      91   1296
# 4  10133 2010-12-01 12:15:00 2011-11-16 15:32:00        101     198   2775
#
#    revenue  avg_unit_price  avg_quantity  avg_revenue  avg_orders  \
# 0   759.89        1.056849     14.205479    10.409452        1.82
# 1   119.09        0.376667     20.625000     4.962083        1.26
# 2    40.53        0.210000      6.433333     1.351000        1.16
# 3   994.84        0.859681     13.787234    10.583404        1.86
# 4  1540.02        0.645800     13.875000     7.700100        1.96
#
#    product_tenure  product_recency
# 0            4280             4131
# 1            4192             3924
# 2            4278             3912
# 3            4280             3907
# 4            4280             3929

# %% [markdown]
# ### 2. Calculate product consumption and repurchase rate

# %%
repurchase_rates = products.get_repurchase_rates(transaction_items)
repurchase_rates.head(3).T
# Out:
#                                                             0  \
# sku                                                     10002
# revenue                                                759.89
# items                                                    1037
# orders                                                     73
# customers                                                  40
# avg_unit_price                                       1.056849
# avg_line_price                                      10.409452
# avg_items_per_order                                 14.205479
# avg_items_per_customer                                 25.925
# purchased_individually                                    0.0
# purchased_once                                           34.0
# bulk_purchases                                           73.0
# bulk_purchase_rate                                        1.0
# repurchases                                              39.0
# repurchase_rate                                      0.534247
# repurchase_rate_label                     Moderate repurchase
# bulk_purchase_rate_label                       Very high bulk
# bulk_and_repurchase_label  Moderate repurchase_Very high bulk
#
#                                                        1  \
# sku                                                10080
# revenue                                           119.09
# items                                                495
# orders                                                24
# customers                                             19
# avg_unit_price                                  0.376667
# avg_line_price                                  4.962083
# avg_items_per_order                               20.625
# avg_items_per_customer                         26.052632
# purchased_individually                               0.0
# purchased_once                                      17.0
# bulk_purchases                                      24.0
# bulk_purchase_rate                                   1.0
# repurchases                                          7.0
# repurchase_rate                                 0.291667
# repurchase_rate_label                     Low repurchase
# bulk_purchase_rate_label                  Very high bulk
# bulk_and_repurchase_label  Low repurchase_Very high bulk
#
#                                                   2
# sku                                           10120
# revenue                                       40.53
# items                                           193
# orders                                           29
# customers                                        25
# avg_unit_price                                 0.21
# avg_line_price                                1.351
# avg_items_per_order                        6.655172
# avg_items_per_customer                         7.72
# purchased_individually                          9.0
# purchased_once                                 22.0
# bulk_purchases                                 20.0
# bulk_purchase_rate                         0.689655
# repurchases                                     7.0
# repurchase_rate                            0.241379
# repurchase_rate_label                Low repurchase
# bulk_purchase_rate_label                  High bulk
# bulk_and_repurchase_label  Low repurchase_High bulk

# %% [markdown]
# # EcommerceTools > Operations

# %%
from ecommercetools import operations

# %% [markdown]
# ### 1. Create an ABC inventory classification

# %%
inventory_classification = operations.get_inventory_classification(transaction_items)
inventory_classification.head()
# Out:
#          sku abc_class  abc_rank
# 4059     DOT         A         1
# 1271   22423         A         2
# 2517   47566         A         3
# 3670  85123A         A         4
# 3659  85099B         A         5

# %%
inventory_classification.groupby(by=['abc_class'])['sku'].nunique()
# Out:
# abc_class
# A     736
# B     411
# C    2923
# Name: sku, dtype: int64

# %% [markdown]
# # EcommerceTools > Customers

# %%
from ecommercetools import customers

# %% [markdown]
# ### 1. Create a customers dataset

# %%
customers_df = customers.get_customers(transaction_items)
customers_df.head()
# Out:
#    customer_id  revenue  orders  skus  items    first_order_date  \
# 0      12346.0     0.00       2     1      0 2011-01-18 10:01:00
# 1      12347.0  4310.00       7     7   2458 2010-12-07 14:57:00
# 2      12348.0  1797.24       4     4   2341 2010-12-16 19:09:00
# 3      12349.0  1757.55       1     1    631 2011-11-21 09:51:00
# 4      12350.0   334.40       1     1    197 2011-02-02 16:01:00
#
#       last_order_date  avg_items  avg_order_value  tenure  recency cohort
# 0 2011-01-18 10:17:00       0.00             0.00    4232     4232  20111
# 1 2011-12-07 15:52:00     351.14           615.71    4273     3908  20104
# 2 2011-09-25 13:13:00     585.25           449.31    4264     3982  20104
# 3 2011-11-21 09:51:00     631.00          1757.55    3925     3925  20114
# 4 2011-02-02 16:01:00     197.00           334.40    4216     4216  20111

# %% [markdown]
# ### 2. Create a customer cohort analysis dataset

# %%
cohorts_df = customers.get_cohorts(transaction_items, period='M')
cohorts_df.head()
# Out:
#     customer_id order_id          order_date acquisition_cohort order_cohort
# 0       17850.0   536365 2010-12-01 08:26:00            2010-12      2010-12
# 7       17850.0   536366 2010-12-01 08:28:00            2010-12      2010-12
# 9       13047.0   536367 2010-12-01 08:34:00            2010-12      2010-12
# 21      13047.0   536368 2010-12-01 08:34:00            2010-12      2010-12
# 25      13047.0   536369 2010-12-01 08:35:00            2010-12      2010-12

# %% [markdown]
# ### 3. Create a customer cohort analysis matrix

# %%
cohort_matrix_df = customers.get_cohort_matrix(transaction_items, period='M', percentage=True)
cohort_matrix_df
# Out:
# periods              0         1         2         3         4         5   \
# acquisition_cohort
# 2010-12             1.0  0.381857  0.334388  0.387131  0.359705  0.396624
# 2011-01             1.0  0.239905  0.282660  0.242280  0.327791  0.299287
# 2011-02             1.0  0.247368  0.192105  0.278947  0.268421  0.247368
# 2011-03             1.0  0.190909  0.254545  0.218182  0.231818  0.177273
# 2011-04             1.0  0.227425  0.220736  0.210702  0.207358  0.237458
# 2011-05             1.0  0.236559  0.172043  0.172043  0.215054  0.243728
# 2011-06             1.0  0.208511  0.187234  0.272340  0.246809  0.336170
# 2011-07             1.0  0.209424  0.204188  0.230366  0.272251  0.115183
# 2011-08             1.0  0.251497  0.251497  0.251497  0.137725       NaN
# 2011-09             1.0  0.298658  0.325503  0.120805       NaN       NaN
# 2011-10             1.0  0.264205  0.130682       NaN       NaN       NaN
# 2011-11             1.0  0.133956       NaN       NaN       NaN       NaN
# 2011-12             1.0       NaN       NaN       NaN       NaN       NaN
#
# periods                   6         7         8         9         10  \
# acquisition_cohort
# 2010-12             0.379747  0.354430  0.354430  0.394515  0.373418
# 2011-01             0.261283  0.256532  0.311164  0.346793  0.368171
# 2011-02             0.255263  0.281579  0.257895  0.313158  0.092105
# 2011-03             0.263636  0.238636  0.288636  0.088636       NaN
# 2011-04             0.230769  0.260870  0.083612       NaN       NaN
# 2011-05             0.265233  0.103943       NaN       NaN       NaN
# 2011-06             0.102128       NaN       NaN       NaN       NaN
# 2011-07                  NaN       NaN       NaN       NaN       NaN
# 2011-08                  NaN       NaN       NaN       NaN       NaN
# 2011-09                  NaN       NaN       NaN       NaN       NaN
# 2011-10                  NaN       NaN       NaN       NaN       NaN
# 2011-11                  NaN       NaN       NaN       NaN       NaN
# 2011-12                  NaN       NaN       NaN       NaN       NaN
#
# periods                   11        12
# acquisition_cohort
# 2010-12             0.500000  0.274262
# 2011-01             0.149644       NaN
# 2011-02                  NaN       NaN
# 2011-03                  NaN       NaN
# 2011-04                  NaN       NaN
# 2011-05                  NaN       NaN
# 2011-06                  NaN       NaN
# 2011-07                  NaN       NaN
# 2011-08                  NaN       NaN
# 2011-09                  NaN       NaN
# 2011-10                  NaN       NaN
# 2011-11                  NaN       NaN
# 2011-12                  NaN       NaN

# %%
cohort_matrix_df = customers.get_cohort_matrix(transaction_items, period='M', percentage=False)
cohort_matrix_df
# Out:
# periods                0      1      2      3      4      5      6      7   \
# acquisition_cohort
# 2010-12             948.0  362.0  317.0  367.0  341.0  376.0  360.0  336.0
# 2011-01             421.0  101.0  119.0  102.0  138.0  126.0  110.0  108.0
# 2011-02             380.0   94.0   73.0  106.0  102.0   94.0   97.0  107.0
# 2011-03             440.0   84.0  112.0   96.0  102.0   78.0  116.0  105.0
# 2011-04             299.0   68.0   66.0   63.0   62.0   71.0   69.0   78.0
# 2011-05             279.0   66.0   48.0   48.0   60.0   68.0   74.0   29.0
# 2011-06             235.0   49.0   44.0   64.0   58.0   79.0   24.0    NaN
# 2011-07             191.0   40.0   39.0   44.0   52.0   22.0    NaN    NaN
# 2011-08             167.0   42.0   42.0   42.0   23.0    NaN    NaN    NaN
# 2011-09             298.0   89.0   97.0   36.0    NaN    NaN    NaN    NaN
# 2011-10             352.0   93.0   46.0    NaN    NaN    NaN    NaN    NaN
# 2011-11             321.0   43.0    NaN    NaN    NaN    NaN    NaN    NaN
# 2011-12              41.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
# periods                8      9      10     11     12
# acquisition_cohort
# 2010-12             336.0  374.0  354.0  474.0  260.0
# 2011-01             131.0  146.0  155.0   63.0    NaN
# 2011-02              98.0  119.0   35.0    NaN    NaN
# 2011-03             127.0   39.0    NaN    NaN    NaN
# 2011-04              25.0    NaN    NaN    NaN    NaN
# 2011-05               NaN    NaN    NaN    NaN    NaN
# 2011-06               NaN    NaN    NaN    NaN    NaN
# 2011-07               NaN    NaN    NaN    NaN    NaN
# 2011-08               NaN    NaN    NaN    NaN    NaN
# 2011-09               NaN    NaN    NaN    NaN    NaN
# 2011-10               NaN    NaN    NaN    NaN    NaN
# 2011-11               NaN    NaN    NaN    NaN    NaN
# 2011-12               NaN    NaN    NaN    NaN    NaN

# %% [markdown]
# ### 4. Create a customer "retention" dataset

# %%
retention_df = customers.get_retention(transactions_df)
retention_df
# Out:
#    acquisition_cohort order_cohort  customers  periods
# 0             2010-12      2010-12        948        0
# 1             2010-12      2011-01        362        1
# 2             2010-12      2011-02        317        2
# 3             2010-12      2011-03        367        3
# 4             2010-12      2011-04        341        4
# ..                ...          ...        ...      ...
# 86            2011-10      2011-11         93        1
# 87            2011-10      2011-12         46        2
# 88            2011-11      2011-11        321        0
# 89            2011-11      2011-12         43        1
# 90            2011-12      2011-12         41        0
#
# [91 rows x 4 columns]

# %% [markdown]
# ### 5. Create an RFM dataset

# %%
rfm_df = customers.get_rfm_segments(customers_df)
rfm_df.head()
# Out:
#    customer_id    acquisition_date        recency_date  recency  frequency  \
# 0      12346.0 2011-01-18 10:01:00 2011-01-18 10:17:00     4232          2
# 1      12350.0 2011-02-02 16:01:00 2011-02-02 16:01:00     4216          1
# 2      12373.0 2011-02-01 13:10:00 2011-02-01 13:10:00     4218          1
# 3      12377.0 2010-12-20 09:37:00 2011-01-28 15:45:00     4221          2
# 4      12386.0 2010-12-08 09:53:00 2011-01-06 12:37:00     4244          2
#
#    monetary  heterogeneity  tenure  r  f  m  h  rfm  rfm_score  \
# 0      0.00              1    4232  1  1  1  1  111          3
# 1    334.40              1    4216  1  1  1  1  111          3
# 2    364.60              1    4218  1  1  1  1  111          3
# 3   1628.12              2    4261  1  1  1  1  111          3
# 4    401.90              2    4273  1  1  1  1  111          3
#
#   rfm_segment_name
# 0            Risky
# 1            Risky
# 2            Risky
# 3            Risky
# 4            Risky

# %%
rfm_df.groupby(by=['rfm_segment_name'])['customer_id'].nunique()
# Out:
# rfm_segment_name
# Hold and improve     443
# Loyal               3079
# Potential loyal      531
# Risky                303
# Star                  16
# Name: customer_id, dtype: int64

# %% [markdown]
# ### 5.1 Create an RFM (H) dataset

# %%
rfm_df.groupby(by=['heterogeneity'])['customer_id'].nunique()
# Out:
# heterogeneity
# 1     1394
# 2      869
# 3      520
# 4      430
# 5      282
# 6      200
# 7      144
# 8      122
# 9       83
# 10      83
# 11      46
# 12      33
# 13      31
# 14      19
# 15      21
# 16      23
# 17      14
# 18      13
# 19      13
# 20       1
# 21       4
# 22       5
# 23       3
# 24       3
# 25       2
# 26       1
# 29       1
# 30       2
# 31       1
# 33       1
# 34       1
# 35       1
# 43       1
# 44       1
# 46       1
# 60       1
# 69       1
# 79       1
# Name: customer_id, dtype: int64

# %% [markdown]
# ### 6. Create a purchase latency dataset

# %%
latency_df = customers.get_latency(transactions_df)
latency_df.head()
# Out:
#    customer_id  frequency        recency_date  recency  avg_latency  \
# 0      12680.0          4 2011-12-09 12:50:00     3907           28
# 1      13113.0         24 2011-12-09 12:49:00     3907           15
# 2      15804.0         13 2011-12-09 12:31:00     3907           15
# 3      13777.0         33 2011-12-09 12:25:00     3907           11
# 4      17581.0         25 2011-12-09 12:21:00     3907           14
#
#    min_latency  max_latency  std_latency        cv  days_to_next_order  \
# 0           16           73    30.859898  1.102139             -3848.0
# 1            0           52    12.060126  0.804008             -3880.0
# 2            1           39    11.008261  0.733884             -3881.0
# 3            0           48    12.055274  1.095934             -3884.0
# 4            0           67    21.974293  1.569592             -3871.0
#
#            label
# 0  Order overdue
# 1  Order overdue
# 2  Order overdue
# 3  Order overdue
# 4  Order overdue

# %% [markdown]
# ### 7. Customer ABC segmentation

# %%
abc_df = customers.get_abc_segments(customers_df, months=12, abc_class_name='abc_class_12m', abc_rank_name='abc_rank_12m')
abc_df.head()
# Out:
#    customer_id abc_class_12m  abc_rank_12m
# 0      12346.0             D           1.0
# 1      12347.0             D           1.0
# 2      12348.0             D           1.0
# 3      12349.0             D           1.0
# 4      12350.0             D           1.0

# %% [markdown]
# ### 8. Predict customer AOV, CLV, and orders
# EcommerceTools allows you to predict the AOV, Customer Lifetime Value (CLV) and expected number of orders via the Gamma-Gamma and BG/NBD models from the excellent Lifetimes package. By passing the dataframe of transactions from get_transactions() to the get_customer_predictions() function, EcommerceTools will fit the BG/NBD and Gamma-Gamma models and predict the AOV, order quantity, and CLV for each customer in the defined number of future days after the end of the observation period.

# %%
customer_predictions = customers.get_customer_predictions(transactions_df, 
                                                          observation_period_end='2011-12-09', 
                                                          days=90)
customer_predictions.head(10)
# Out:
#    customer_id  predicted_purchases         aov         clv
# 0      12346.0             0.188830         NaN         NaN
# 1      12347.0             1.408736  569.978836  836.846896
# 2      12348.0             0.805907  333.784235  308.247354
# 3      12349.0             0.855607         NaN         NaN
# 4      12350.0             0.196304         NaN         NaN
# 5      12352.0             1.682277  376.175359  647.826169
# 6      12353.0             0.272541         NaN         NaN
# 7      12354.0             0.247183         NaN         NaN
# 8      12355.0             0.262909         NaN         NaN
# 9      12356.0             0.645368  324.039419  256.855226

# %% [markdown]
# # EcommerceTools > Advertising

# %%
from ecommercetools import advertising

# %% [markdown]
# ### 1. Create paid search keywords

# %%
product_names = ['fly rods', 'fly reels']
keywords_prepend = ['buy', 'best', 'cheap', 'reduced']
keywords_append = ['for sale', 'price', 'promotion', 'promo', 'coupon', 'voucher', 'shop', 'suppliers']
campaign_name = 'fly_fishing'

keywords = advertising.generate_ad_keywords(product_names, keywords_prepend, keywords_append, campaign_name)
keywords.head()
# Out:
#     product            keywords match_type campaign_name
# 0  fly rods          [fly rods]      Exact   fly_fishing
# 1  fly rods      [buy fly rods]      Exact   fly_fishing
# 2  fly rods     [best fly rods]      Exact   fly_fishing
# 3  fly rods    [cheap fly rods]      Exact   fly_fishing
# 4  fly rods  [reduced fly rods]      Exact   fly_fishing

# %% [markdown]
# ### 2. Create paid search ad copy using Spintax

# %%
text = "Fly Reels from {Orvis|Loop|Sage|Airflo|Nautilus} for {trout|salmon|grayling|pike}"
spin = advertising.generate_spintax(text, single=False)

spin
# Out:
# ['Fly Reels from Orvis for trout',
#  'Fly Reels from Orvis for salmon',
#  'Fly Reels from Orvis for grayling',
#  'Fly Reels from Orvis for pike',
#  'Fly Reels from Loop for trout',
#  'Fly Reels from Loop for salmon',
#  'Fly Reels from Loop for grayling',
#  'Fly Reels from Loop for pike',
#  'Fly Reels from Sage for trout',
#  'Fly Reels from Sage for salmon',
#  'Fly Reels from Sage for grayling',
#  'Fly Reels from Sage for pike',
#  'Fly Reels from Airflo for trout',
#  'Fly Reels from Airflo for salmon',
#  'Fly Reels from Airflo for grayling',
#  'Fly Reels from Airflo for pike',
#  'Fly Reels from Nautilus for trout',
#  'Fly Reels from Nautilus for salmon',
#  'Fly Reels from Nautilus for grayling',
#  'Fly Reels from Nautilus for pike']
